# %% [markdown]
# # 04 · Explicabilidad SHAP y LIME — AnemIA
# Genera importancia global/local (SHAP) y explicación local (LIME) para el caso de Juliaca.

# %%
import os, sys
sys.path.insert(0, os.path.abspath('..'))
os.chdir('..')
from explainability import shap_explainer, lime_explainer
case = {'Sexo':'F','EdadMeses':53.62,'Juntos':0,'SIS':1,'Qaliwarma':0,'Cred':1,
        'Suplementacion':1,'Consejeria':0,'Sesion':0,'Hemoglobina':13.7,
        'ProvinciaREN':'SANROMAN','AlturaREN':3877}
shap_explainer.global_importance('random_forest')

# %%
shap_explainer.local_explanation(case, 'random_forest')

# %%
lime_explainer.local_explanation(case, 'random_forest')
