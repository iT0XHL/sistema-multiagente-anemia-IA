# %% [markdown]
# # 03 · Entrenamiento XGBoost — AnemIA
# Entrena XGBoost y lo compara con Random Forest.

# %%
import os, sys
sys.path.insert(0, os.path.abspath('..'))
os.chdir('..')
from ml import train_xgboost
metrics = train_xgboost.train('data/raw/dataset.csv')
metrics

# %%
from ml import compare_models
compare_models.main()
